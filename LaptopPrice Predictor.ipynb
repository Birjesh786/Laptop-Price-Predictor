# %% [markdown]
# ![1.png](attachment:1.png)

# %%
#Impport the libraries and dataset

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn

ld = pd.read_csv('laptop_data.csv')

# %%
ld.sample(5)
# Out:
#       Unnamed: 0 Company  TypeName  Inches             ScreenResolution  \
# 699          699      HP  Notebook    15.6  IPS Panel Full HD 1920x1080
# 78            78    Acer  Notebook    15.6            Full HD 1920x1080
# 766          766    Asus  Notebook    17.3                     1366x768
# 1062        1062    Dell  Notebook    15.6            Full HD 1920x1080
# 302          302  Lenovo  Notebook    17.3                     1600x900
#
#                                        Cpu  Ram     Memory  \
# 699             Intel Core i7 7500U 2.7GHz  4GB  500GB HDD
# 78              Intel Core i3 7130U 2.7GHz  4GB    1TB HDD
# 766   Intel Pentium Quad Core N4200 1.1GHz  4GB    1TB HDD
# 1062            Intel Core i5 7200U 2.5GHz  4GB    1TB HDD
# 302             Intel Core i5 7200U 2.5GHz  6GB    1TB HDD
#
#                           Gpu       OpSys  Weight       Price
# 699            AMD Radeon 530  Windows 10   2.1kg  36709.9200
# 78       Nvidia GeForce MX130  Windows 10   2.2kg  28238.4000
# 766      Nvidia GeForce 920MX  Windows 10   2.8kg  25059.7152
# 1062        Intel HD Graphics  Windows 10  2.25kg  29783.5200
# 302   Nvidia GeForce GTX 940M  Windows 10   2.8kg  34578.7200

# %% [markdown]
# # Basic understanding for data

# %%
print(ld.shape)
# Out:
# (1303, 12)

# %%
print(ld.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB
# None

# %%
print(ld.duplicated().sum())
# Out:
# 0

# %%
print(ld.isnull().sum())
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
#Drop unrequired column
ld.drop(columns=['Unnamed: 0'],inplace=True)

# %%
ld.sample(5)
# Out:
#      Company  TypeName  Inches   ScreenResolution  \
# 64        HP  Notebook    15.6  Full HD 1920x1080
# 1104  Lenovo    Gaming    15.6  Full HD 1920x1080
# 321   Lenovo  Notebook    17.3           1600x900
# 1120    Vero  Notebook    13.3  Full HD 1920x1080
# 483    Chuwi  Notebook    15.6  Full HD 1920x1080
#
#                               Cpu   Ram              Memory  \
# 64     Intel Core i5 7200U 2.5GHz   8GB           256GB SSD
# 1104  Intel Core i7 7700HQ 2.8GHz  16GB           512GB SSD
# 321    Intel Core i5 7200U 2.5GHz   4GB             1TB HDD
# 1120  Intel Atom X5-Z8350 1.44GHz   4GB  32GB Flash Storage
# 483   Intel Atom x5-Z8350 1.44GHz   4GB  64GB Flash Storage
#
#                              Gpu       OpSys  Weight      Price
# 64         Intel HD Graphics 620  Windows 10  1.86kg  36763.200
# 1104  Nvidia GeForce GTX 1050 Ti  Windows 10   2.4kg  63882.720
# 321         Nvidia GeForce 920MX  Windows 10  2.79kg  31381.920
# 1120       Intel HD Graphics 400  Windows 10  1.35kg  10442.880
# 483            Intel HD Graphics  Windows 10  1.89kg  13261.392

# %% [markdown]
# #### Now split the mixed varibels.

# %%
#Ram---
ld['Ram'] = ld['Ram'].str.replace('GB','')

#Weight---
ld['Weight'] = ld['Weight'].str.replace('kg','')

#Change data type----
ld['Ram'] = ld['Ram'].astype('int32')
ld['Weight'] = ld['Weight'].astype('float32')

# %%
ld.sample(5)
# Out:
#     Company   TypeName  Inches   ScreenResolution  \
# 147    Asus   Notebook    15.6  Full HD 1920x1080
# 611    Dell     Gaming    15.6  Full HD 1920x1080
# 28     Dell  Ultrabook    15.6  Full HD 1920x1080
# 966    Dell   Notebook    15.6           1366x768
# 949    Acer   Notebook    14.0           1366x768
#
#                                       Cpu  Ram                  Memory  \
# 147  Intel Celeron Dual Core N3350 1.1GHz    4                 1TB HDD
# 611           Intel Core i7 6700HQ 2.6GHz   16                 1TB HDD
# 28             Intel Core i7 8650U 1.9GHz    8  256GB SSD +  256GB SSD
# 966            Intel Core i5 7200U 2.5GHz    4               500GB HDD
# 949  Intel Celeron Dual Core N3060 1.6GHz    4      32GB Flash Storage
#
#                                 Gpu       OpSys  Weight       Price
# 147           Intel HD Graphics 500  Windows 10    2.00  18328.3200
# 611  Nvidia GeForce GTX 960<U+039C>  Windows 10    2.59  46833.6528
# 28           Intel UHD Graphics 620  Windows 10    1.88  69157.4400
# 966           Intel HD Graphics 620  Windows 10    1.90  43956.0000
# 949           Intel HD Graphics 400   Chrome OS    1.68  18594.7200

# %%
print(ld.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB
# None

# %% [markdown]
# # EDA with Data

# %% [markdown]
# #### Price Distriution $

# %%
sns.distplot(ld['Price'],
             hist_kws={'color':'purple', 'edgecolor':'black',
                       'linewidth':.5, 'linestyle':'-'})
sns.set(rc={"figure.figsize":(7, 5)})
plt.title("Price Distriution")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Company 🏢

# %%
#Company wise laptops-------------
sns.countplot(x ='Company', data = ld,palette ='PiYG')
plt.xticks(rotation='vertical')
plt.title("Company wise laptops")
sns.set(rc={"figure.figsize":(8, 8)})
plt.show()

#Company with Price---------------
sns.barplot(x="Company", y="Price", data=ld, palette="PiYG")
plt.xticks(rotation='vertical')
sns.set(rc={"figure.figsize":(7, 7)})
plt.title("Company wise Price")
plt.show()

# %% [markdown]
# ### TypeName 💻

# %%
#TypeName wise laptops-------------
sns.countplot(x ='TypeName', data = ld,palette ='PiYG')
plt.xticks(rotation='vertical')
plt.title("TypeName wise laptops")
sns.set(rc={"figure.figsize":(8, 8)})
plt.show()

#TypeName with Price---------------
sns.barplot(x="TypeName", y="Price", data=ld, palette="PiYG")
plt.xticks(rotation='vertical')
sns.set(rc={"figure.figsize":(7, 7)})
plt.title("TypeName wise Price")
plt.show()

# %% [markdown]
# #### Inches

# %%
#DIst plot---------
sns.distplot(ld['Inches'],
             hist_kws={'color':'blue', 'edgecolor':'#aaff00',
                       'linewidth':.5, 'linestyle':'--'})
sns.set(rc={"figure.figsize":(7, 5)})
plt.title("Inches")
plt.show()

#Scatter plot--------------
seaborn.scatterplot(x="Inches",
                    y="Price",
                    hue="Inches",
                    marker = '+',
                    data=ld)
plt.title("Inches with Price")
sns.set(rc={"figure.figsize":(8, 8)})
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Work with Screen Resolution

# %%
print(ld['ScreenResolution'].value_counts())
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# Touchscreen 2400x1600                              3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 1920x1200                        1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: ScreenResolution, dtype: int64

# %%
#Split the column based on Touchscreen
ld['Touchscreen'] = ld['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
ld['Ips'] = ld['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
ld.sample(10)
# Out:
#      Company   TypeName  Inches             ScreenResolution  \
# 708   Lenovo   Notebook    14.0            Full HD 1920x1080
# 381   Lenovo   Notebook    15.6            Full HD 1920x1080
# 365       HP   Notebook    15.6                     1366x768
# 257       HP   Notebook    17.3  IPS Panel Full HD 1920x1080
# 927       HP   Notebook    15.6            Full HD 1920x1080
# 741     Dell   Notebook    15.6                     1366x768
# 1113      HP  Ultrabook    13.3            Full HD 1920x1080
# 832     Asus   Notebook    15.6            Full HD 1920x1080
# 63      Asus   Notebook    14.0            Full HD 1920x1080
# 60      Dell   Notebook    17.3            Full HD 1920x1080
#
#                                        Cpu  Ram                Memory  \
# 708            Intel Core i5 6300HQ 2.3GHz    8             256GB SSD
# 381               Intel Core i3 6006U 2GHz    4             128GB SSD
# 365   Intel Pentium Quad Core N3710 1.6GHz    8               2TB HDD
# 257             Intel Core i7 8550U 1.8GHz   16               1TB HDD
# 927             Intel Core i5 6200U 2.3GHz    8             256GB SSD
# 741               Intel Core i3 6006U 2GHz    8             256GB SSD
# 1113            Intel Core i7 6500U 2.5GHz    8             512GB SSD
# 832             Intel Core i5 7200U 2.5GHz    4               1TB HDD
# 63              Intel Core i5 8250U 1.6GHz    8             256GB SSD
# 60              Intel Core i7 8550U 1.8GHz   16  256GB SSD +  2TB HDD
#
#                          Gpu       OpSys  Weight      Price  Touchscreen  Ips
# 708    Intel HD Graphics 520  Windows 10    1.80   63456.48            0    0
# 381    Intel HD Graphics 520       No OS    1.85   21498.48            0    0
# 365    Intel HD Graphics 405  Windows 10    2.04   20725.92            0    0
# 257     Nvidia GeForce MX150  Windows 10    2.90   56423.52            0    1
# 927    Intel HD Graphics 520  Windows 10    2.31   62071.20            0    0
# 741    Intel HD Graphics 520  Windows 10    2.00   35431.20            0    0
# 1113   Intel HD Graphics 520  Windows 10    1.16  104908.32            0    0
# 832       Nvidia GeForce 920       Linux    2.10   27652.32            0    0
# 63    Intel UHD Graphics 620  Windows 10    1.40   50136.48            0    0
# 60            AMD Radeon 530  Windows 10    2.80   69210.72            0    0

# %%
#Touchscreen
sns.countplot(x ='Touchscreen', data = ld,palette ='PiYG')
plt.xticks(rotation='vertical')
plt.title("TypeName wise laptops")
sns.set(rc={"figure.figsize":(5, 5)})
plt.show()

sns.barplot(x="Touchscreen", y="Price", data=ld, palette="PiYG")
plt.xticks(rotation='vertical')
sns.set(rc={"figure.figsize":(5, 5)})
plt.title("TypeName wise Price")
plt.show()

#IPs
sns.countplot(x ='Ips', data = ld,palette ='PiYG')
plt.xticks(rotation='vertical')
plt.title("TypeName wise laptops")
sns.set(rc={"figure.figsize":(5, 5)})
plt.show()

#TypeName with Price---------------
sns.barplot(x="Ips", y="Price", data=ld, palette="PiYG")
plt.xticks(rotation='vertical')
sns.set(rc={"figure.figsize":(5, 5)})
plt.title("TypeName wise Price")
plt.show()

# %%
new = ld['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
#Again split screenresolution column
ld['X_res'] = new[0]
ld['Y_res'] = new[1]

# %%
ld.sample(5)
# Out:
#         Company   TypeName  Inches       ScreenResolution  \
# 193      Lenovo   Notebook    17.3               1600x900
# 835        Dell     Gaming    15.6      Full HD 1920x1080
# 104   Microsoft  Ultrabook    13.5  Touchscreen 2256x1504
# 805          HP    Netbook    12.5               1366x768
# 1258     Lenovo   Notebook    15.6      Full HD 1920x1080
#
#                               Cpu  Ram                Memory  \
# 193    Intel Core i5 8250U 1.6GHz    8             256GB SSD
# 835   Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 104    Intel Core i5 7200U 2.5GHz    8             256GB SSD
# 805    Intel Core i5 7300U 2.6GHz    8             256GB SSD
# 1258   Intel Core i7 6500U 2.5GHz    8          1.0TB Hybrid
#
#                           Gpu         OpSys  Weight        Price  Touchscreen  \
# 193      Nvidia GeForce MX150         No OS   2.800   37189.4400            0
# 835   Nvidia GeForce GTX 1070    Windows 10   3.210  147832.2864            0
# 104     Intel HD Graphics 620  Windows 10 S   1.252   71395.2000            1
# 805     Intel HD Graphics 620    Windows 10   1.260   74005.9200            0
# 1258       AMD Radeon R5 M330     Windows 7   2.320   47685.6000            0
#
#       Ips             X_res Y_res
# 193     0              1600   900
# 835     0      Full HD 1920  1080
# 104     0  Touchscreen 2256  1504
# 805     0              1366   768
# 1258    0      Full HD 1920  1080

# %%
#Edit X-res
ld['X_res'] = ld['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
ld.sample(2)
# Out:
#     Company  TypeName  Inches             ScreenResolution  \
# 397  Lenovo  Notebook    14.0  IPS Panel Full HD 1920x1080
# 454    Dell  Notebook    15.6            Full HD 1920x1080
#
#                             Cpu  Ram                Memory  \
# 397  Intel Core i5 7200U 2.5GHz    8             256GB SSD
# 454  Intel Core i7 8550U 1.8GHz    8  128GB SSD +  1TB HDD
#
#                        Gpu       OpSys  Weight     Price  Touchscreen  Ips  \
# 397  Intel HD Graphics 620  Windows 10    1.90  49976.64            0    1
# 454         AMD Radeon 530  Windows 10    2.36  52161.12            0    0
#
#     X_res Y_res
# 397  1920  1080
# 454  1920  1080

# %%
#Change data type
ld['X_res'] = ld['X_res'].astype('int')
ld['Y_res'] = ld['Y_res'].astype('int')

# %%
ld.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# memory usage: 132.5+ KB

# %% [markdown]
# ### Work with Price

# %%
ld.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %%
ld['ppi'] = (((ld['X_res']**2) + (ld['Y_res']**2))**0.5/ld['Inches']).astype('float')

# %%
ld.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
ld.sample(5)
# Out:
#     Company  TypeName  Inches             ScreenResolution  \
# 303  Lenovo  Notebook    15.6                     1366x768
# 223      HP  Notebook    15.6            Full HD 1920x1080
# 212      HP  Notebook    15.6            Full HD 1920x1080
# 814    Dell  Notebook    15.6            Full HD 1920x1080
# 485  Lenovo  Notebook    14.0  IPS Panel Full HD 1920x1080
#
#                             Cpu  Ram     Memory                     Gpu  \
# 303  Intel Core i5 7200U 2.5GHz    8    2TB HDD    Nvidia GeForce 940MX
# 223  Intel Core i5 8250U 1.6GHz    8    1TB HDD  Intel UHD Graphics 620
# 212    Intel Core i3 6006U 2GHz    4  500GB HDD   Intel HD Graphics 520
# 814  Intel Core i5 7200U 2.5GHz    8  256GB SSD      AMD Radeon R5 M420
# 485  Intel Core i5 8250U 1.6GHz    8  256GB SSD  Intel UHD Graphics 620
#
#           OpSys  Weight       Price  Touchscreen  Ips  X_res  Y_res  \
# 303       No OS    2.20  29250.7200            0    0   1366    768
# 223  Windows 10    2.10  42304.3200            0    0   1920   1080
# 212       No OS    2.10  18594.7200            0    0   1920   1080
# 814  Windows 10    2.18  42081.0768            0    0   1920   1080
# 485  Windows 10    1.75  55890.7200            0    1   1920   1080
#
#             ppi
# 303  100.454670
# 223  141.211998
# 212  141.211998
# 814  141.211998
# 485  157.350512

# %%
#drop screenresolution, Inches, X_res and Y_res
ld.drop(columns=['ScreenResolution','Inches','X_res','Y_res'],inplace=True)

# %%
ld.sample(2)
# Out:
#     Company            TypeName                         Cpu  Ram     Memory  \
# 413    Acer  2 in 1 Convertible  Intel Core i7 6500U 2.5GHz    8  256GB SSD
# 541    Dell            Notebook    Intel Core i3 6006U 2GHz    4  128GB SSD
#
#                        Gpu       OpSys  Weight       Price  Touchscreen  Ips  \
# 413  Intel HD Graphics 520  Windows 10     1.6  42038.4528            1    1
# 541  Intel HD Graphics 520  Windows 10     1.6  39207.1536            0    0
#
#             ppi
# 413  165.632118
# 541  157.350512

# %% [markdown]
# ### Work with CPU

# %%
ld['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
#split first 3-words
ld['Cpu Name'] = ld['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
ld.sample(2)
# Out:
#     Company  TypeName                          Cpu  Ram                Memory  \
# 148     MSI    Gaming  Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 235    Dell  Notebook   Intel Core i7 7500U 2.7GHz   16             256GB SSD
#
#                          Gpu       OpSys  Weight      Price  Touchscreen  Ips  \
# 148  Nvidia GeForce GTX 1070  Windows 10    2.90  108105.12            0    0
# 235       AMD Radeon R7 M445       Linux    2.36   47898.72            0    0
#
#             ppi       Cpu Name
# 148  127.335675  Intel Core i7
# 235  141.211998  Intel Core i7

# %%
#CPU name extration function
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
ld['Cpu brand'] = ld['Cpu Name'].apply(fetch_processor)

# %%
ld.sample(2)
# Out:
#     Company   TypeName                          Cpu  Ram     Memory  \
# 543    Acer     Gaming  Intel Core i5 7300HQ 2.5GHz    8    1TB HDD
# 678      LG  Ultrabook   Intel Core i7 8550U 1.8GHz    8  512GB SSD
#
#                          Gpu       OpSys  Weight      Price  Touchscreen  Ips  \
# 543  Nvidia GeForce GTX 1050       Linux    2.40   42517.44            0    0
# 678    Intel HD Graphics 620  Windows 10    1.09  122490.72            0    1
#
#             ppi       Cpu Name      Cpu brand
# 543  141.211998  Intel Core i5  Intel Core i5
# 678  141.211998  Intel Core i7  Intel Core i7

# %%
#Cpu brand
sns.countplot(x ='Cpu brand', data = ld,palette ='PiYG')
plt.xticks(rotation='vertical')
plt.title("Cpu brand wise laptops")
sns.set(rc={"figure.figsize":(5, 5)})
plt.show()

sns.barplot(x="Cpu brand", y="Price", data=ld, palette="PiYG")
plt.xticks(rotation='vertical')
sns.set(rc={"figure.figsize":(5, 5)})
plt.title("Cpu brand wise Price")
plt.show()

# %%
#drop cpu and cpu name 
ld.drop(columns=['Cpu','Cpu Name'],inplace=True)

# %%
ld.sample(2)
# Out:
#       Company  TypeName  Ram                Memory                      Gpu  \
# 593   Samsung  Notebook   16  128GB SSD +  1TB HDD  Nvidia GeForce GTX 1050
# 1252   Lenovo  Notebook    6             128GB SSD     Nvidia GeForce 920MX
#
#            OpSys  Weight     Price  Touchscreen  Ips         ppi  \
# 593   Windows 10     2.5  90522.72            0    0  141.211998
# 1252  Windows 10     2.4  30316.32            0    0  141.211998
#
#           Cpu brand
# 593   Intel Core i7
# 1252  Intel Core i3

# %% [markdown]
# ### Work with RAM

# %%
#RAM
sns.countplot(x ='Ram', data = ld,palette ='PiYG')
plt.xticks(rotation='vertical')
plt.title("Ram wise laptops")
sns.set(rc={"figure.figsize":(5, 5)})
plt.show()

sns.barplot(x="Ram", y="Price", data=ld, palette="PiYG")
plt.xticks(rotation='vertical')
sns.set(rc={"figure.figsize":(5, 5)})
plt.title("Ram wise Price")
plt.show()

# %% [markdown]
# ### Work with Memory

# %%
print(ld['Memory'].value_counts())
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 32GB HDD                           1
# 64GB SSD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: Memory, dtype: int64

# %%
#Split the memory column based on SSD, HDD, TB, Hybrid and Flash storage

ld['Memory'] = ld['Memory'].astype(str).replace('\.0', '', regex=True)
ld["Memory"] = ld["Memory"].str.replace('GB', '')
ld["Memory"] = ld["Memory"].str.replace('TB', '000')
new = ld["Memory"].str.split("+", n = 1, expand = True)

ld["first"]= new[0]
ld["first"]=ld["first"].str.strip()

ld["second"]= new[1]

ld["Layer1HDD"] = ld["first"].apply(lambda x: 1 if "HDD" in x else 0)
ld["Layer1SSD"] = ld["first"].apply(lambda x: 1 if "SSD" in x else 0)
ld["Layer1Hybrid"] = ld["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
ld["Layer1Flash_Storage"] = ld["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

ld['first'] = ld['first'].str.replace(r'\D', '')

ld["second"].fillna("0", inplace = True)

ld["Layer2HDD"] = ld["second"].apply(lambda x: 1 if "HDD" in x else 0)
ld["Layer2SSD"] = ld["second"].apply(lambda x: 1 if "SSD" in x else 0)
ld["Layer2Hybrid"] = ld["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
ld["Layer2Flash_Storage"] = ld["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

ld['second'] = ld['second'].str.replace(r'\D', '')

ld["first"] = ld["first"].astype(int)
ld["second"] = ld["second"].astype(int)

ld["HDD"]=(ld["first"]*ld["Layer1HDD"]+ld["second"]*ld["Layer2HDD"])
ld["SSD"]=(ld["first"]*ld["Layer1SSD"]+ld["second"]*ld["Layer2SSD"])
ld["Hybrid"]=(ld["first"]*ld["Layer1Hybrid"]+ld["second"]*ld["Layer2Hybrid"])
ld["Flash_Storage"]=(ld["first"]*ld["Layer1Flash_Storage"]+ld["second"]*ld["Layer2Flash_Storage"])

ld.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_26944/2715484543.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   ld['first'] = ld['first'].str.replace(r'\D', '')
# C:\Users\HP\AppData\Local\Temp/ipykernel_26944/2715484543.py:27: FutureWarning: The default value of regex will change from True to False in a future version.
#   ld['second'] = ld['second'].str.replace(r'\D', '')

# %%
ld.sample(5)
# Out:
#      Company            TypeName  Ram               Memory  \
# 545       HP            Notebook    4              128 SSD
# 984  Toshiba            Notebook    4              500 HDD
# 940       HP              Gaming    8  128 SSD +  1000 HDD
# 470       HP  2 in 1 Convertible    8              512 SSD
# 58       MSI              Gaming   16  256 SSD +  2000 HDD
#
#                          Gpu       OpSys  Weight      Price  Touchscreen  Ips  \
# 545    Intel HD Graphics 620  Windows 10    2.10   37589.04            0    0
# 984    Intel HD Graphics 520  Windows 10    1.75   48751.20            0    0
# 940  Nvidia GeForce GTX 965M  Windows 10    2.75   74538.72            0    1
# 470   Intel UHD Graphics 620  Windows 10    1.29  106506.72            1    1
# 58   Nvidia GeForce GTX 1070  Windows 10    2.43  130482.72            0    0
#
#             ppi      Cpu brand   HDD  SSD  Hybrid  Flash_Storage
# 545  141.211998  Intel Core i3     0  128       0              0
# 984  111.935204  Intel Core i5   500    0       0              0
# 940  127.335675  Intel Core i5  1000  128       0              0
# 470  331.264236  Intel Core i7     0  512       0              0
# 58   127.335675  Intel Core i7  2000  256       0              0

# %%
plt.figure(figsize=(16, 6))
colormap = sns.color_palette("PiYG")
sns.heatmap(ld.corr(), annot=True, cmap=colormap).set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12)
plt.show()

# %%
ld.drop(columns=['Memory','Hybrid','Flash_Storage'],inplace=True)

# %%
ld.sample(2)
# Out:
#      Company   TypeName  Ram                     Gpu     OpSys  Weight  \
# 1193   Apple  Ultrabook    8  Intel HD Graphics 5300  Mac OS X    0.92
# 886     Dell   Notebook    4     AMD Radeon R5 M420X     Linux    2.18
#
#           Price  Touchscreen  Ips         ppi              Cpu brand   HDD  \
# 1193  61964.640            0    1  226.415547  Other Intel Processor     0
# 886   24279.696            0    0  100.454670          Intel Core i3  1000
#
#       SSD
# 1193    0
# 886     0

# %% [markdown]
# ### Work with GPU

# %%
print(ld['Gpu'].value_counts())
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
#split first 3-words
ld['Gpu Brand'] = ld['Gpu'].apply(lambda x:x.split()[0])

# %%
ld.head(2)
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
#
#         Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD Gpu Brand
# 0  71378.6832            0    1  226.983005  Intel Core i5    0  128     Intel
# 1  47895.5232            0    0  127.677940  Intel Core i5    0    0     Intel

# %%
#drop GPU 
ld.drop(columns=['Gpu'],inplace=True)

# %%
ld['Gpu Brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu Brand, dtype: int64

# %%
#drop ARM GPU
ld = ld[ld['Gpu Brand'] != 'ARM']

# %%
sns.barplot(x="Gpu Brand", y="Price", data=ld, palette="PiYG")
plt.xticks(rotation='vertical')
sns.set(rc={"figure.figsize":(5, 5)})
plt.title("Gpu Brand wise Price")
plt.show()

# %% [markdown]
# ### Work with Ops

# %%
print(ld['OpSys'].value_counts())
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x="OpSys", y="Price", data=ld, palette="PiYG")
plt.xticks(rotation='vertical')
sns.set(rc={"figure.figsize":(5, 5)})
plt.title("OpSys wise Price")
plt.show()

# %%
#OPs extrating function

def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others'

# %%
ld['os'] = ld['OpSys'].apply(cat_os)

# %%
ld.head(2)
# Out:
#   Company   TypeName  Ram  OpSys  Weight       Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37  71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34  47895.5232            0    0
#
#           ppi      Cpu brand  HDD  SSD Gpu Brand   os
# 0  226.983005  Intel Core i5    0  128     Intel  Mac
# 1  127.677940  Intel Core i5    0    0     Intel  Mac

# %%
sns.barplot(x="os", y="Price", data=ld, palette="PiYG")
plt.xticks(rotation='vertical')
sns.set(rc={"figure.figsize":(5, 5)})
plt.title("OpSys wise Price")
plt.show()

# %%
ld.drop(columns=['OpSys'],inplace=True)

# %%
ld.sample(2)
# Out:
#     Company  TypeName  Ram  Weight      Price  Touchscreen  Ips         ppi  \
# 184  Xiaomi  Notebook    8    1.95   63882.72            0    1  141.211998
# 552    Dell    Gaming   16    4.42  143802.72            0    1  127.335675
#
#          Cpu brand   HDD  SSD Gpu Brand       os
# 184  Intel Core i5     0  256    Nvidia   Others
# 552  Intel Core i7  1000  256    Nvidia  Windows

# %% [markdown]
# ### Work with Weight

# %%
#Distplot------------
sns.distplot(ld['Weight'],
             hist_kws={'color':'purple', 'edgecolor':'black',
                       'linewidth':.5, 'linestyle':'-'})
sns.set(rc={"figure.figsize":(7, 5)})
plt.title("Price Distriution")
plt.show()

#Scatterplot------------
seaborn.scatterplot(x="Weight",
                    y="Price",
                    hue="Price",
                    marker = '+',
                    data=ld)
plt.title("Inches with Price")
sns.set(rc={"figure.figsize":(8, 8)})
plt.show()

#Let's see corr on weight
plt.figure(figsize=(16, 6))
colormap = sns.color_palette("PiYG")
sns.heatmap(ld.corr(), annot=True, cmap=colormap).set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Work with price

# %%
#Apply Log in price function
sns.distplot(np.log(ld['Price']),hist_kws={'color':'purple', 'edgecolor':'black',
                       'linewidth':.5, 'linestyle':'-'})
sns.set(rc={"figure.figsize":(7, 5)})
plt.title("Price Distriution") #It's normal distribution
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # It's time to Model Building

# %%
#Divide the data for x and y
X = ld.drop(columns=['Price'])
y = np.log(ld['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
#                   Cpu brand   HDD  SSD Gpu Brand       os
# 0             Intel Core i5     0  128     Intel      Mac
# 1             Intel Core i5     0    0     Intel      Mac
# 2             Intel Core i5     0  256     Intel   Others
# 3             Intel Core i7     0  512       AMD      Mac
# 4             Intel Core i5     0  256     Intel      Mac
# ...                     ...   ...  ...       ...      ...
# 1298          Intel Core i7     0  128     Intel  Windows
# 1299          Intel Core i7     0  512     Intel  Windows
# 1300  Other Intel Processor     0    0     Intel  Windows
# 1301          Intel Core i7  1000    0       AMD  Windows
# 1302  Other Intel Processor   500    0     Intel  Windows
#
# [1302 rows x 12 columns]

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %% [markdown]
# ### Train_Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454670
# 1141      MSI              Gaming    8    2.40            0    0  141.211998
# 1049     Asus             Netbook    4    1.20            0    0  135.094211
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1  141.211998
# 878      Dell            Notebook    4    2.18            0    0  141.211998
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook    4    2.20            0    0  100.454670
# 299      Asus           Ultrabook   16    1.63            0    0  141.211998
# 493      Acer            Notebook    8    2.20            0    0  100.454670
# 527    Lenovo            Notebook    8    2.20            0    0  100.454670
# 1193    Apple           Ultrabook    8    0.92            0    1  226.415547
#
#                   Cpu brand   HDD  SSD Gpu Brand       os
# 183           Intel Core i5     0  128     Intel  Windows
# 1141          Intel Core i7  1000  128    Nvidia  Windows
# 1049  Other Intel Processor     0    0     Intel   Others
# 1020          Intel Core i3  1000    0     Intel  Windows
# 878           Intel Core i5  1000  128    Nvidia  Windows
# ...                     ...   ...  ...       ...      ...
# 466           Intel Core i3   500    0    Nvidia  Windows
# 299           Intel Core i7     0  512    Nvidia  Windows
# 493           AMD Processor  1000    0       AMD  Windows
# 527           Intel Core i3  2000    0    Nvidia   Others
# 1193  Other Intel Processor     0    0     Intel      Mac
#
# [1106 rows x 12 columns]

# %%
X_test
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 248       HP            Notebook    4    1.49            0    1  165.632118
# 555     Asus            Notebook    4    2.00            0    0  100.454670
# 1251      HP            Notebook    4    1.86            0    0  100.454670
# 547   Lenovo            Notebook    4    2.15            0    0  141.211998
# 885       HP  2 in 1 Convertible    4    1.28            1    0  165.632118
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1129      HP              Gaming    8    3.35            0    1  127.335675
# 172   Lenovo            Notebook    4    2.20            0    0  100.454670
# 322     Asus            Notebook    8    2.00            0    0  157.350512
# 996       HP           Ultrabook    8    1.11            1    1  165.632118
# 470       HP  2 in 1 Convertible    8    1.29            1    1  331.264236
#
#                   Cpu brand   HDD  SSD Gpu Brand       os
# 248           Intel Core i5   500    0     Intel  Windows
# 555   Other Intel Processor   500    0     Intel   Others
# 1251          AMD Processor   500    0       AMD  Windows
# 547           Intel Core i5  1000    0     Intel   Others
# 885           Intel Core i5     0  256     Intel  Windows
# ...                     ...   ...  ...       ...      ...
# 1129          Intel Core i5  1000  128    Nvidia  Windows
# 172           AMD Processor   500    0       AMD   Others
# 322           Intel Core i7     0  256     Intel  Windows
# 996           Intel Core i7     0  256     Intel  Windows
# 470           Intel Core i7     0  512     Intel  Windows
#
# [196 rows x 12 columns]

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\programdata\anaconda3\lib\site-packages (1.7.2)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.7.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.20.3)

# %%
#Import all ML algoritham 

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
#creating dictionary for storing different models accuracy
model_comparison={}

# %% [markdown]
# ### Model 1 : Linear Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

accuracies = cross_val_score(estimator = pipe, X = X_train, y = y_train, cv = 5)

print(f"R2 Score : {r2_score(y_test,y_pred)*100:.2f}%") 
print(f"MAE : {mean_absolute_error(y_test,y_pred)*100:.2f}%")
print(f"MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))

model_comparison['Linear Regression']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),mean_absolute_error(y_test,y_pred),(accuracies.mean())]
# Out:
# R2 Score : 80.73%
# MAE : 21.02%
# MSE : 7.37%
# Cross Val Accuracy: 81.79 %

# %% [markdown]
# ### Model 2 : Ridge Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

accuracies = cross_val_score(estimator = pipe, X = X_train, y = y_train, cv = 5)

print(f"R2 Score : {r2_score(y_test,y_pred)*100:.2f}%") 
print(f"MAE : {mean_absolute_error(y_test,y_pred)*100:.2f}%")
print(f"MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))

model_comparison['Linear Regression']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),mean_absolute_error(y_test,y_pred),(accuracies.mean())]
# Out:
# R2 Score : 81.27%
# MAE : 20.93%
# MSE : 7.16%
# Cross Val Accuracy: 80.76 %

# %% [markdown]
# ### Model 3 : Lasso Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

accuracies = cross_val_score(estimator = pipe, X = X_train, y = y_train, cv = 5)

print(f"R2 Score : {r2_score(y_test,y_pred)*100:.2f}%") 
print(f"MAE : {mean_absolute_error(y_test,y_pred)*100:.2f}%")
print(f"MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))

model_comparison['Lasso Regression']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),mean_absolute_error(y_test,y_pred),(accuracies.mean())]
# Out:
# R2 Score : 80.72%
# MAE : 21.11%
# MSE : 7.38%
# Cross Val Accuracy: 80.92 %

# %% [markdown]
# ### Model 4 : KNN Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

accuracies = cross_val_score(estimator = pipe, X = X_train, y = y_train, cv = 5)

print(f"R2 Score : {r2_score(y_test,y_pred)*100:.2f}%") 
print(f"MAE : {mean_absolute_error(y_test,y_pred)*100:.2f}%")
print(f"MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))

model_comparison['KNN Regression']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),mean_absolute_error(y_test,y_pred),(accuracies.mean())]
# Out:
# R2 Score : 80.22%
# MAE : 19.32%
# MSE : 7.57%
# Cross Val Accuracy: 76.48 %

# %% [markdown]
# ### Model 5 : DecisionTree Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

accuracies = cross_val_score(estimator = pipe, X = X_train, y = y_train, cv = 5)

print(f"R2 Score : {r2_score(y_test,y_pred)*100:.2f}%") 
print(f"MAE : {mean_absolute_error(y_test,y_pred)*100:.2f}%")
print(f"MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))

model_comparison['DecisionTree Regression']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),mean_absolute_error(y_test,y_pred),(accuracies.mean())]
# Out:
# R2 Score : 84.26%
# MAE : 18.13%
# MSE : 6.02%
# Cross Val Accuracy: 79.45 %

# %% [markdown]
# ### Model 6 : SVR Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

accuracies = cross_val_score(estimator = pipe, X = X_train, y = y_train, cv = 5)

print(f"R2 Score : {r2_score(y_test,y_pred)*100:.2f}%") 
print(f"MAE : {mean_absolute_error(y_test,y_pred)*100:.2f}%")
print(f"MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))

model_comparison['SVR Regression']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),mean_absolute_error(y_test,y_pred),(accuracies.mean())]
# Out:
# R2 Score : 80.83%
# MAE : 20.24%
# MSE : 7.33%
# Cross Val Accuracy: 80.24 %

# %% [markdown]
# ### Model 7 : RandomForest Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.10,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

accuracies = cross_val_score(estimator = pipe, X = X_train, y = y_train, cv = 5)

print(f"R2 Score : {r2_score(y_test,y_pred)*100:.2f}%") 
print(f"MAE : {mean_absolute_error(y_test,y_pred)*100:.2f}%")
print(f"MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))

model_comparison['RandomForest Regression']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),mean_absolute_error(y_test,y_pred),(accuracies.mean())]
# Out:
# R2 Score : 89.49%
# MAE : 15.55%
# MSE : 4.02%
# Cross Val Accuracy: 85.91 %

# %% [markdown]
# ### Model 8 : ExtraTrees Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = ExtraTreesRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

accuracies = cross_val_score(estimator = pipe, X = X_train, y = y_train, cv = 5)

print(f"R2 Score : {r2_score(y_test,y_pred)*100:.2f}%") 
print(f"MAE : {mean_absolute_error(y_test,y_pred)*100:.2f}%")
print(f"MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))

model_comparison['ExtraTrees Regression']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),mean_absolute_error(y_test,y_pred),(accuracies.mean())]
# Out:
# R2 Score : 87.54%
# MAE : 15.98%
# MSE : 4.77%
# Cross Val Accuracy: 85.70 %

# %% [markdown]
# ### Model 8 : AdaBoost Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

accuracies = cross_val_score(estimator = pipe, X = X_train, y = y_train, cv = 5)

print(f"R2 Score : {r2_score(y_test,y_pred)*100:.2f}%") 
print(f"MAE : {mean_absolute_error(y_test,y_pred)*100:.2f}%")
print(f"MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))

model_comparison['AdaBoost Regression']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),mean_absolute_error(y_test,y_pred),(accuracies.mean())]
# Out:
# R2 Score : 80.01%
# MAE : 22.80%
# MSE : 7.65%
# Cross Val Accuracy: 78.41 %

# %% [markdown]
# ### Model 9 : GradientBoosting Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

accuracies = cross_val_score(estimator = pipe, X = X_train, y = y_train, cv = 5)

print(f"R2 Score : {r2_score(y_test,y_pred)*100:.2f}%") 
print(f"MAE : {mean_absolute_error(y_test,y_pred)*100:.2f}%")
print(f"MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))

model_comparison['GradientBoosting Regression']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),mean_absolute_error(y_test,y_pred),(accuracies.mean())]
# Out:
# R2 Score : 88.43%
# MAE : 15.88%
# MSE : 4.43%
# Cross Val Accuracy: 87.89 %

# %% [markdown]
# ### Model 10 : XGB Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

accuracies = cross_val_score(estimator = pipe, X = X_train, y = y_train, cv = 5)

print(f"R2 Score : {r2_score(y_test,y_pred)*100:.2f}%") 
print(f"MAE : {mean_absolute_error(y_test,y_pred)*100:.2f}%")
print(f"MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))

model_comparison['XGB Regression']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),mean_absolute_error(y_test,y_pred),(accuracies.mean())]
# Out:
# R2 Score : 88.12%
# MAE : 16.50%
# MSE : 4.55%
# Cross Val Accuracy: 86.95 %

# %% [markdown]
# ### Model 11 : Voting Regression

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


rf = RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb = XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)
et = ExtraTreesRegressor(n_estimators=100,random_state=3,max_samples=0.5,max_features=0.75,max_depth=10)

step2 = VotingRegressor([('rf', rf), ('gbdt', gbdt), ('xgb',xgb), ('et',et)],weights=[5,1,1,1])

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

accuracies = cross_val_score(estimator = pipe, X = X_train, y = y_train, cv = 5)

print(f"R2 Score : {r2_score(y_test,y_pred)*100:.2f}%") 
print(f"MAE : {mean_absolute_error(y_test,y_pred)*100:.2f}%")
print(f"MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))

model_comparison['Voting Regression']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),mean_absolute_error(y_test,y_pred),(accuracies.mean())]
# Out:
# R2 Score : 89.11%
# MAE : 15.78%
# MSE : 4.17%
# Cross Val Accuracy: 87.66 %

# %% [markdown]
# ### Model 12 : Stacking Regression

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

accuracies = cross_val_score(estimator = pipe, X = X_train, y = y_train, cv = 5)

print(f"R2 Score : {r2_score(y_test,y_pred)*100:.2f}%") 
print(f"MAE : {mean_absolute_error(y_test,y_pred)*100:.2f}%")
print(f"MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))

model_comparison['Stacking Regression']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),mean_absolute_error(y_test,y_pred),(accuracies.mean())]
# Out:
# R2 Score : 87.97%
# MAE : 16.74%
# MSE : 4.60%
# Cross Val Accuracy: 86.47 %

# %% [markdown]
# # Model Comparison

# %%
Model_com_ld=pd.DataFrame(model_comparison).T
Model_com_ld.columns=['R2 Score','MAE','MSE','Cross Val Accuracy']
Model_com_ld=Model_com_ld.sort_values(by='R2 Score',ascending=False)

# %%
Model = Model_com_ld.style.format("{:.2%}").background_gradient(cmap='RdPu')

# %%
Max = Model_com_ld.style.highlight_max().set_caption("Maximum Score in each Column").format("{:.2%}")

# %%
Min = Model_com_ld.style.highlight_min().set_caption("Minimum Score in each Column").format("{:.2%}")

# %%
Model
# Out:
# <style type="text/css">
# #T_b50a2_row0_col0, #T_b50a2_row2_col3, #T_b50a2_row11_col1, #T_b50a2_row11_col2 {
#   background-color: #49006a;
#   color: #f1f1f1;
# }
# #T_b50a2_row0_col1, #T_b50a2_row0_col2, #T_b50a2_row10_col3, #T_b50a2_row11_col0 {
#   background-color: #fff7f3;
#   color: #000000;
# }
# #T_b50a2_row0_col3 {
#   background-color: #8e017a;
#   color: #f1f1f1;
# }
# #T_b50a2_row1_col0 {
#   background-color: #58006e;
#   color: #f1f1f1;
# }
# #T_b50a2_row1_col1 {
#   background-color: #fef0ec;
#   color: #000000;
# }
# #T_b50a2_row1_col2 {
#   background-color: #fff2ee;
#   color: #000000;
# }
# #T_b50a2_row1_col3, #T_b50a2_row10_col1 {
#   background-color: #51006c;
#   color: #f1f1f1;
# }
# #T_b50a2_row2_col0 {
#   background-color: #740175;
#   color: #f1f1f1;
# }
# #T_b50a2_row2_col1 {
#   background-color: #fde3e0;
#   color: #000000;
# }
# #T_b50a2_row2_col2 {
#   background-color: #feefeb;
#   color: #000000;
# }
# #T_b50a2_row3_col0 {
#   background-color: #820178;
#   color: #f1f1f1;
# }
# #T_b50a2_row3_col1 {
#   background-color: #fddcd8;
#   color: #000000;
# }
# #T_b50a2_row3_col2 {
#   background-color: #fddfdc;
#   color: #000000;
# }
# #T_b50a2_row3_col3 {
#   background-color: #690173;
#   color: #f1f1f1;
# }
# #T_b50a2_row4_col0 {
#   background-color: #890179;
#   color: #f1f1f1;
# }
# #T_b50a2_row4_col1, #T_b50a2_row4_col2 {
#   background-color: #fdd8d5;
#   color: #000000;
# }
# #T_b50a2_row4_col3 {
#   background-color: #790177;
#   color: #f1f1f1;
# }
# #T_b50a2_row5_col0 {
#   background-color: #9b017b;
#   color: #f1f1f1;
# }
# #T_b50a2_row5_col1 {
#   background-color: #fccfcb;
#   color: #000000;
# }
# #T_b50a2_row5_col2 {
#   background-color: #feece9;
#   color: #000000;
# }
# #T_b50a2_row5_col3 {
#   background-color: #96017b;
#   color: #f1f1f1;
# }
# #T_b50a2_row6_col0 {
#   background-color: #f87fa9;
#   color: #f1f1f1;
# }
# #T_b50a2_row6_col1 {
#   background-color: #ec529d;
#   color: #f1f1f1;
# }
# #T_b50a2_row6_col2 {
#   background-color: #faa5b7;
#   color: #000000;
# }
# #T_b50a2_row6_col3 {
#   background-color: #fcc2bf;
#   color: #000000;
# }
# #T_b50a2_row7_col0 {
#   background-color: #fddedb;
#   color: #000000;
# }
# #T_b50a2_row7_col1 {
#   background-color: #7d0177;
#   color: #f1f1f1;
# }
# #T_b50a2_row7_col2 {
#   background-color: #b10580;
#   color: #f1f1f1;
# }
# #T_b50a2_row7_col3 {
#   background-color: #fa9eb5;
#   color: #000000;
# }
# #T_b50a2_row8_col0 {
#   background-color: #fee7e4;
#   color: #000000;
# }
# #T_b50a2_row8_col1 {
#   background-color: #6b0173;
#   color: #f1f1f1;
# }
# #T_b50a2_row8_col2 {
#   background-color: #d52b93;
#   color: #f1f1f1;
# }
# #T_b50a2_row8_col3 {
#   background-color: #fbadb9;
#   color: #000000;
# }
# #T_b50a2_row9_col0 {
#   background-color: #fee9e6;
#   color: #000000;
# }
# #T_b50a2_row9_col1 {
#   background-color: #660172;
#   color: #f1f1f1;
# }
# #T_b50a2_row9_col2 {
#   background-color: #a6017d;
#   color: #f1f1f1;
# }
# #T_b50a2_row9_col3 {
#   background-color: #fa99b3;
#   color: #000000;
# }
# #T_b50a2_row10_col0 {
#   background-color: #fff3f0;
#   color: #000000;
# }
# #T_b50a2_row10_col2 {
#   background-color: #f35f9f;
#   color: #f1f1f1;
# }
# #T_b50a2_row11_col3 {
#   background-color: #fdd7d3;
#   color: #000000;
# }
# </style>
# <table id="T_b50a2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >R2 Score</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >Cross Val Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b50a2_level0_row0" class="row_heading level0 row0" >RandomForest Regression</th>
#       <td id="T_b50a2_row0_col0" class="data row0 col0" >89.49%</td>
#       <td id="T_b50a2_row0_col1" class="data row0 col1" >4.02%</td>
#       <td id="T_b50a2_row0_col2" class="data row0 col2" >15.55%</td>
#       <td id="T_b50a2_row0_col3" class="data row0 col3" >85.91%</td>
#     </tr>
#     <tr>
#       <th id="T_b50a2_level0_row1" class="row_heading level0 row1" >Voting Regression</th>
#       <td id="T_b50a2_row1_col0" class="data row1 col0" >89.11%</td>
#       <td id="T_b50a2_row1_col1" class="data row1 col1" >4.17%</td>
#       <td id="T_b50a2_row1_col2" class="data row1 col2" >15.78%</td>
#       <td id="T_b50a2_row1_col3" class="data row1 col3" >87.66%</td>
#     </tr>
#     <tr>
#       <th id="T_b50a2_level0_row2" class="row_heading level0 row2" >GradientBoosting Regression</th>
#       <td id="T_b50a2_row2_col0" class="data row2 col0" >88.43%</td>
#       <td id="T_b50a2_row2_col1" class="data row2 col1" >4.43%</td>
#       <td id="T_b50a2_row2_col2" class="data row2 col2" >15.88%</td>
#       <td id="T_b50a2_row2_col3" class="data row2 col3" >87.89%</td>
#     </tr>
#     <tr>
#       <th id="T_b50a2_level0_row3" class="row_heading level0 row3" >XGB Regression</th>
#       <td id="T_b50a2_row3_col0" class="data row3 col0" >88.12%</td>
#       <td id="T_b50a2_row3_col1" class="data row3 col1" >4.55%</td>
#       <td id="T_b50a2_row3_col2" class="data row3 col2" >16.50%</td>
#       <td id="T_b50a2_row3_col3" class="data row3 col3" >86.95%</td>
#     </tr>
#     <tr>
#       <th id="T_b50a2_level0_row4" class="row_heading level0 row4" >Stacking Regression</th>
#       <td id="T_b50a2_row4_col0" class="data row4 col0" >87.97%</td>
#       <td id="T_b50a2_row4_col1" class="data row4 col1" >4.60%</td>
#       <td id="T_b50a2_row4_col2" class="data row4 col2" >16.74%</td>
#       <td id="T_b50a2_row4_col3" class="data row4 col3" >86.47%</td>
#     </tr>
#     <tr>
#       <th id="T_b50a2_level0_row5" class="row_heading level0 row5" >ExtraTrees Regression</th>
#       <td id="T_b50a2_row5_col0" class="data row5 col0" >87.54%</td>
#       <td id="T_b50a2_row5_col1" class="data row5 col1" >4.77%</td>
#       <td id="T_b50a2_row5_col2" class="data row5 col2" >15.98%</td>
#       <td id="T_b50a2_row5_col3" class="data row5 col3" >85.70%</td>
#     </tr>
#     <tr>
#       <th id="T_b50a2_level0_row6" class="row_heading level0 row6" >DecisionTree Regression</th>
#       <td id="T_b50a2_row6_col0" class="data row6 col0" >84.26%</td>
#       <td id="T_b50a2_row6_col1" class="data row6 col1" >6.02%</td>
#       <td id="T_b50a2_row6_col2" class="data row6 col2" >18.13%</td>
#       <td id="T_b50a2_row6_col3" class="data row6 col3" >79.45%</td>
#     </tr>
#     <tr>
#       <th id="T_b50a2_level0_row7" class="row_heading level0 row7" >Linear Regression</th>
#       <td id="T_b50a2_row7_col0" class="data row7 col0" >81.27%</td>
#       <td id="T_b50a2_row7_col1" class="data row7 col1" >7.16%</td>
#       <td id="T_b50a2_row7_col2" class="data row7 col2" >20.93%</td>
#       <td id="T_b50a2_row7_col3" class="data row7 col3" >80.76%</td>
#     </tr>
#     <tr>
#       <th id="T_b50a2_level0_row8" class="row_heading level0 row8" >SVR Regression</th>
#       <td id="T_b50a2_row8_col0" class="data row8 col0" >80.83%</td>
#       <td id="T_b50a2_row8_col1" class="data row8 col1" >7.33%</td>
#       <td id="T_b50a2_row8_col2" class="data row8 col2" >20.24%</td>
#       <td id="T_b50a2_row8_col3" class="data row8 col3" >80.24%</td>
#     </tr>
#     <tr>
#       <th id="T_b50a2_level0_row9" class="row_heading level0 row9" >Lasso Regression</th>
#       <td id="T_b50a2_row9_col0" class="data row9 col0" >80.72%</td>
#       <td id="T_b50a2_row9_col1" class="data row9 col1" >7.38%</td>
#       <td id="T_b50a2_row9_col2" class="data row9 col2" >21.11%</td>
#       <td id="T_b50a2_row9_col3" class="data row9 col3" >80.92%</td>
#     </tr>
#     <tr>
#       <th id="T_b50a2_level0_row10" class="row_heading level0 row10" >KNN Regression</th>
#       <td id="T_b50a2_row10_col0" class="data row10 col0" >80.22%</td>
#       <td id="T_b50a2_row10_col1" class="data row10 col1" >7.57%</td>
#       <td id="T_b50a2_row10_col2" class="data row10 col2" >19.32%</td>
#       <td id="T_b50a2_row10_col3" class="data row10 col3" >76.48%</td>
#     </tr>
#     <tr>
#       <th id="T_b50a2_level0_row11" class="row_heading level0 row11" >AdaBoost Regression</th>
#       <td id="T_b50a2_row11_col0" class="data row11 col0" >80.01%</td>
#       <td id="T_b50a2_row11_col1" class="data row11 col1" >7.65%</td>
#       <td id="T_b50a2_row11_col2" class="data row11 col2" >22.80%</td>
#       <td id="T_b50a2_row11_col3" class="data row11 col3" >78.41%</td>
#     <

# %%
Min
# Out:
# <style type="text/css">
# #T_c3601_row0_col1, #T_c3601_row0_col2, #T_c3601_row10_col3, #T_c3601_row11_col0 {
#   background-color: yellow;
# }
# </style>
# <table id="T_c3601_">
#   <caption>Minimum Score in each Column</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >R2 Score</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >Cross Val Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3601_level0_row0" class="row_heading level0 row0" >RandomForest Regression</th>
#       <td id="T_c3601_row0_col0" class="data row0 col0" >89.49%</td>
#       <td id="T_c3601_row0_col1" class="data row0 col1" >4.02%</td>
#       <td id="T_c3601_row0_col2" class="data row0 col2" >15.55%</td>
#       <td id="T_c3601_row0_col3" class="data row0 col3" >85.91%</td>
#     </tr>
#     <tr>
#       <th id="T_c3601_level0_row1" class="row_heading level0 row1" >Voting Regression</th>
#       <td id="T_c3601_row1_col0" class="data row1 col0" >89.11%</td>
#       <td id="T_c3601_row1_col1" class="data row1 col1" >4.17%</td>
#       <td id="T_c3601_row1_col2" class="data row1 col2" >15.78%</td>
#       <td id="T_c3601_row1_col3" class="data row1 col3" >87.66%</td>
#     </tr>
#     <tr>
#       <th id="T_c3601_level0_row2" class="row_heading level0 row2" >GradientBoosting Regression</th>
#       <td id="T_c3601_row2_col0" class="data row2 col0" >88.43%</td>
#       <td id="T_c3601_row2_col1" class="data row2 col1" >4.43%</td>
#       <td id="T_c3601_row2_col2" class="data row2 col2" >15.88%</td>
#       <td id="T_c3601_row2_col3" class="data row2 col3" >87.89%</td>
#     </tr>
#     <tr>
#       <th id="T_c3601_level0_row3" class="row_heading level0 row3" >XGB Regression</th>
#       <td id="T_c3601_row3_col0" class="data row3 col0" >88.12%</td>
#       <td id="T_c3601_row3_col1" class="data row3 col1" >4.55%</td>
#       <td id="T_c3601_row3_col2" class="data row3 col2" >16.50%</td>
#       <td id="T_c3601_row3_col3" class="data row3 col3" >86.95%</td>
#     </tr>
#     <tr>
#       <th id="T_c3601_level0_row4" class="row_heading level0 row4" >Stacking Regression</th>
#       <td id="T_c3601_row4_col0" class="data row4 col0" >87.97%</td>
#       <td id="T_c3601_row4_col1" class="data row4 col1" >4.60%</td>
#       <td id="T_c3601_row4_col2" class="data row4 col2" >16.74%</td>
#       <td id="T_c3601_row4_col3" class="data row4 col3" >86.47%</td>
#     </tr>
#     <tr>
#       <th id="T_c3601_level0_row5" class="row_heading level0 row5" >ExtraTrees Regression</th>
#       <td id="T_c3601_row5_col0" class="data row5 col0" >87.54%</td>
#       <td id="T_c3601_row5_col1" class="data row5 col1" >4.77%</td>
#       <td id="T_c3601_row5_col2" class="data row5 col2" >15.98%</td>
#       <td id="T_c3601_row5_col3" class="data row5 col3" >85.70%</td>
#     </tr>
#     <tr>
#       <th id="T_c3601_level0_row6" class="row_heading level0 row6" >DecisionTree Regression</th>
#       <td id="T_c3601_row6_col0" class="data row6 col0" >84.26%</td>
#       <td id="T_c3601_row6_col1" class="data row6 col1" >6.02%</td>
#       <td id="T_c3601_row6_col2" class="data row6 col2" >18.13%</td>
#       <td id="T_c3601_row6_col3" class="data row6 col3" >79.45%</td>
#     </tr>
#     <tr>
#       <th id="T_c3601_level0_row7" class="row_heading level0 row7" >Linear Regression</th>
#       <td id="T_c3601_row7_col0" class="data row7 col0" >81.27%</td>
#       <td id="T_c3601_row7_col1" class="data row7 col1" >7.16%</td>
#       <td id="T_c3601_row7_col2" class="data row7 col2" >20.93%</td>
#       <td id="T_c3601_row7_col3" class="data row7 col3" >80.76%</td>
#     </tr>
#     <tr>
#       <th id="T_c3601_level0_row8" class="row_heading level0 row8" >SVR Regression</th>
#       <td id="T_c3601_row8_col0" class="data row8 col0" >80.83%</td>
#       <td id="T_c3601_row8_col1" class="data row8 col1" >7.33%</td>
#       <td id="T_c3601_row8_col2" class="data row8 col2" >20.24%</td>
#       <td id="T_c3601_row8_col3" class="data row8 col3" >80.24%</td>
#     </tr>
#     <tr>
#       <th id="T_c3601_level0_row9" class="row_heading level0 row9" >Lasso Regression</th>
#       <td id="T_c3601_row9_col0" class="data row9 col0" >80.72%</td>
#       <td id="T_c3601_row9_col1" class="data row9 col1" >7.38%</td>
#       <td id="T_c3601_row9_col2" class="data row9 col2" >21.11%</td>
#       <td id="T_c3601_row9_col3" class="data row9 col3" >80.92%</td>
#     </tr>
#     <tr>
#       <th id="T_c3601_level0_row10" class="row_heading level0 row10" >KNN Regression</th>
#       <td id="T_c3601_row10_col0" class="data row10 col0" >80.22%</td>
#       <td id="T_c3601_row10_col1" class="data row10 col1" >7.57%</td>
#       <td id="T_c3601_row10_col2" class="data row10 col2" >19.32%</td>
#       <td id="T_c3601_row10_col3" class="data row10 col3" >76.48%</td>
#     </tr>
#     <tr>
#       <th id="T_c3601_level0_row11" class="row_heading level0 row11" >AdaBoost Regression</th>
#       <td id="T_c3601_row11_col0" class="data row11 col0" >80.01%</td>
#       <td id="T_c3601_row11_col1" class="data row11 col1" >7.65%</td>
#       <td id="T_c3601_row11_col2" class="data row11 col2" >22.80%</td>
#       <td id="T_c3601_row11_col3" class="data row11 col3" >78.41%</td>
#     </tr>
#   </tbody>
# </table>

# %%
Max
# Out:
# <style type="text/css">
# #T_bf6c0_row0_col0, #T_bf6c0_row2_col3, #T_bf6c0_row11_col1, #T_bf6c0_row11_col2 {
#   background-color: yellow;
# }
# </style>
# <table id="T_bf6c0_">
#   <caption>Maximum Score in each Column</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >R2 Score</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >Cross Val Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf6c0_level0_row0" class="row_heading level0 row0" >RandomForest Regression</th>
#       <td id="T_bf6c0_row0_col0" class="data row0 col0" >89.49%</td>
#       <td id="T_bf6c0_row0_col1" class="data row0 col1" >4.02%</td>
#       <td id="T_bf6c0_row0_col2" class="data row0 col2" >15.55%</td>
#       <td id="T_bf6c0_row0_col3" class="data row0 col3" >85.91%</td>
#     </tr>
#     <tr>
#       <th id="T_bf6c0_level0_row1" class="row_heading level0 row1" >Voting Regression</th>
#       <td id="T_bf6c0_row1_col0" class="data row1 col0" >89.11%</td>
#       <td id="T_bf6c0_row1_col1" class="data row1 col1" >4.17%</td>
#       <td id="T_bf6c0_row1_col2" class="data row1 col2" >15.78%</td>
#       <td id="T_bf6c0_row1_col3" class="data row1 col3" >87.66%</td>
#     </tr>
#     <tr>
#       <th id="T_bf6c0_level0_row2" class="row_heading level0 row2" >GradientBoosting Regression</th>
#       <td id="T_bf6c0_row2_col0" class="data row2 col0" >88.43%</td>
#       <td id="T_bf6c0_row2_col1" class="data row2 col1" >4.43%</td>
#       <td id="T_bf6c0_row2_col2" class="data row2 col2" >15.88%</td>
#       <td id="T_bf6c0_row2_col3" class="data row2 col3" >87.89%</td>
#     </tr>
#     <tr>
#       <th id="T_bf6c0_level0_row3" class="row_heading level0 row3" >XGB Regression</th>
#       <td id="T_bf6c0_row3_col0" class="data row3 col0" >88.12%</td>
#       <td id="T_bf6c0_row3_col1" class="data row3 col1" >4.55%</td>
#       <td id="T_bf6c0_row3_col2" class="data row3 col2" >16.50%</td>
#       <td id="T_bf6c0_row3_col3" class="data row3 col3" >86.95%</td>
#     </tr>
#     <tr>
#       <th id="T_bf6c0_level0_row4" class="row_heading level0 row4" >Stacking Regression</th>
#       <td id="T_bf6c0_row4_col0" class="data row4 col0" >87.97%</td>
#       <td id="T_bf6c0_row4_col1" class="data row4 col1" >4.60%</td>
#       <td id="T_bf6c0_row4_col2" class="data row4 col2" >16.74%</td>
#       <td id="T_bf6c0_row4_col3" class="data row4 col3" >86.47%</td>
#     </tr>
#     <tr>
#       <th id="T_bf6c0_level0_row5" class="row_heading level0 row5" >ExtraTrees Regression</th>
#       <td id="T_bf6c0_row5_col0" class="data row5 col0" >87.54%</td>
#       <td id="T_bf6c0_row5_col1" class="data row5 col1" >4.77%</td>
#       <td id="T_bf6c0_row5_col2" class="data row5 col2" >15.98%</td>
#       <td id="T_bf6c0_row5_col3" class="data row5 col3" >85.70%</td>
#     </tr>
#     <tr>
#       <th id="T_bf6c0_level0_row6" class="row_heading level0 row6" >DecisionTree Regression</th>
#       <td id="T_bf6c0_row6_col0" class="data row6 col0" >84.26%</td>
#       <td id="T_bf6c0_row6_col1" class="data row6 col1" >6.02%</td>
#       <td id="T_bf6c0_row6_col2" class="data row6 col2" >18.13%</td>
#       <td id="T_bf6c0_row6_col3" class="data row6 col3" >79.45%</td>
#     </tr>
#     <tr>
#       <th id="T_bf6c0_level0_row7" class="row_heading level0 row7" >Linear Regression</th>
#       <td id="T_bf6c0_row7_col0" class="data row7 col0" >81.27%</td>
#       <td id="T_bf6c0_row7_col1" class="data row7 col1" >7.16%</td>
#       <td id="T_bf6c0_row7_col2" class="data row7 col2" >20.93%</td>
#       <td id="T_bf6c0_row7_col3" class="data row7 col3" >80.76%</td>
#     </tr>
#     <tr>
#       <th id="T_bf6c0_level0_row8" class="row_heading level0 row8" >SVR Regression</th>
#       <td id="T_bf6c0_row8_col0" class="data row8 col0" >80.83%</td>
#       <td id="T_bf6c0_row8_col1" class="data row8 col1" >7.33%</td>
#       <td id="T_bf6c0_row8_col2" class="data row8 col2" >20.24%</td>
#       <td id="T_bf6c0_row8_col3" class="data row8 col3" >80.24%</td>
#     </tr>
#     <tr>
#       <th id="T_bf6c0_level0_row9" class="row_heading level0 row9" >Lasso Regression</th>
#       <td id="T_bf6c0_row9_col0" class="data row9 col0" >80.72%</td>
#       <td id="T_bf6c0_row9_col1" class="data row9 col1" >7.38%</td>
#       <td id="T_bf6c0_row9_col2" class="data row9 col2" >21.11%</td>
#       <td id="T_bf6c0_row9_col3" class="data row9 col3" >80.92%</td>
#     </tr>
#     <tr>
#       <th id="T_bf6c0_level0_row10" class="row_heading level0 row10" >KNN Regression</th>
#       <td id="T_bf6c0_row10_col0" class="data row10 col0" >80.22%</td>
#       <td id="T_bf6c0_row10_col1" class="data row10 col1" >7.57%</td>
#       <td id="T_bf6c0_row10_col2" class="data row10 col2" >19.32%</td>
#       <td id="T_bf6c0_row10_col3" class="data row10 col3" >76.48%</td>
#     </tr>
#     <tr>
#       <th id="T_bf6c0_level0_row11" class="row_heading level0 row11" >AdaBoost Regression</th>
#       <td id="T_bf6c0_row11_col0" class="data row11 col0" >80.01%</td>
#       <td id="T_bf6c0_row11_col1" class="data row11 col1" >7.65%</td>
#       <td id="T_bf6c0_row11_col2" class="data row11 col2" >22.80%</td>
#       <td id="T_bf6c0_row11_col3" class="data row11 col3" >78.41%</td>
#     </tr>
#   </tbody>
# </table>
